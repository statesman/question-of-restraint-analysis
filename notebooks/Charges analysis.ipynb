# %% [markdown]
# # Charges analysis
#
# Looking at how many times different charges come up. The raw data accessed was pulled from our database, then saved into `data_raw` folder as `offenses-YYYY-MM-DD_v.csv`.
#
# ## Goals of this analysis
# - See which offenses appear the most
# - Isolate and count the cases where the only charge is in a short list including 'Evading arrest', 'Resisting arrest', 'Interfering with police duties' and perhaps a few others.

# %%
import agate
import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import the files we need

# %%
# This is the data of each decedant and the offense they have
offense_file = '../data_raw/offenses_latest.csv'
# This is a list of all the possible offenses
offense_table_file = '../data_raw/offense_table.csv'
# This is the death tables, after it is run through the File processing notebook
deaths_file = '../exports/deaths_latest.csv'

# %% [markdown]
# ### Import deaths data

# %%
# sets data types on fields agate got wrong
specified_data_types = {
    'tracked_cause': agate.Text(),
    'offense': agate.Text(),
    'case_study': agate.Text(),
    'official_discipline': agate.Text()
}

# this pulls the deaths file that is exported in the File processing notebook
deaths = agate.Table.from_csv(deaths_file, column_types=specified_data_types)

print(deaths)
# Out:
# | column               | data_type |
# | -------------------- | --------- |
# | id                   | Number    |
# | ag_report_url        | Text      |
# | first_name           | Text      |
# | middle_name          | Text      |
# | last_name            | Text      |
# | suffix               | Text      |
# | slug                 | Text      |
# | race                 | Text      |
# | gender               | Text      |
# | date_of_birth        | Date      |
# | date_of_death        | Date      |
# | age                  | Number    |
# | agency               | Number    |
# | restrained           | Boolean   |
# | tazed                | Boolean   |
# | times_tazed          | Number    |
# | pepper_sprayed       | Boolean   |
# | official_discipline  | Text      |
# | grand_jury_result    | Text      |
# | mental_health_issues | Boolean   |
# | manner_of_death      | Text      |
# | drug_intoxication    | Boolean   |
# | cause_of_death       | Text      |
# | tracked_cause        | Text      |
# | offense              | Text      |
# | investigation        | Text      |
# | notes                | Text      |
# | ag_summary           | Text      |
# | reporter_assigned    | Text      |
# | record_status        | Text      |
# | case_study           | Text      |
# | story_summary        | Text      |
# | photo                | Text      |
# | cropping             | Number    |
# | race_name            | Text      |
# | manner_name          | Text      |
# | grand_jury_name      | Text      |
# | discipline_name      | Text      |

# %% [markdown]
# ### Import offense table
#
# This is the table of the actual offenses and their ID.

# %%
# read in the offenses data
offenses = agate.Table.from_csv(offense_file)

# print the column names
print(offenses)
# Out:
# | column    | data_type |
# | --------- | --------- |
# | id        | Number    |
# | Full Name | Text      |
# | race      | Text      |
# | offense   | Text      |

# %%
# print first 5 rows to see what we are looking at
offenses.limit(5).print_table(max_column_width=80)
# Out:
# |  id | Full Name                  | race | offense                                                |
# | --- | -------------------------- | ---- | ------------------------------------------------------ |
# | 612 | Anthony Timpa              | w    | APOWW/mental health hold                               |
# | 423 | Juan Carlos Reyes-Gallardo | h    | Public intoxication                                    |
# | 528 | Micheal Olveda             | h    | Outstanding warrants                                   |
# | 613 | Manuel Delacruz            | h    | Taking or attempting to take weapon from peace officer |
# | 424 | Mario Evans                | b    | Public intoxication                                    |

# %% [markdown]
# ### Import offenses data

# %%
# read in the list of offense choices
offenses_table = agate.Table.from_csv(offense_table_file)

# print the column names
print(offenses_table)
# Out:
# | column  | data_type |
# | ------- | --------- |
# | id      | Number    |
# | offense | Text      |

# %% [markdown]
# ## Offenses that appear the most

# %%
# pivot offenses table and order by most
offenses_pivot = offenses.pivot('offense').order_by('Count', reverse=True)

# print offenses list
offenses_pivot.print_table(max_column_width=None, max_rows=None)
# Out:
# | offense                                                    | Count |
# | ---------------------------------------------------------- | ----- |
# | Resisting arrest                                           |    59 |
# | Public intoxication                                        |    54 |
# | Assault on public servant                                  |    38 |
# | Evading arrest                                             |    32 |
# | Possession of a controlled substance                       |    31 |
# | APOWW/mental health hold                                   |    22 |
# | Burglary of a habitation                                   |    14 |
# | Criminal mischief                                          |    13 |
# | Outstanding warrants                                       |    12 |
# | None listed                                                |    11 |
# | DWI                                                        |    10 |
# | Criminal trespass                                          |    10 |
# | Aggravated assault                                         |     8 |
# | Assault                                                    |     8 |
# | Assault family violence                                    |     8 |
# | Traffic violations                                         |     7 |
# | Disorderly conduct                                         |     6 |
# | Aggravated assault with a deadly weapon                    |     6 |
# | Tampering with evidence                                    |     5 |
# | Driving without a license                                  |     5 |
# | Aggravated robbery                                         |     4 |
# | Burglary of motor vehicle                                  |     3 |
# | Possession drug paraphernalia                              |     3 |
# | Theft $50-$500                                             |     3 |
# | Manufacture/distribution of controlled substance           |     3 |
# | Parole violation                                           |     2 |
# | Indecent exposure                                          |     2 |
# | Assault of a child                                         |     2 |
# | Unauthorized use of motor vehicle                          |     2 |
# | Possession/use abusable volatile chemical (inhalant)       |     2 |
# | Robbery                                                    |     2 |
# | Theft <$20,000                                             |     2 |
# | Probation revocation                                       |     2 |
# | Domestic violence                                          |     2 |
# | Discharging a weapon in city limits                        |     2 |
# | Taking or attempting to take weapon from peace officer     |     1 |
# | False identification                                       |     1 |
# | Failure to stop and render aid                             |     1 |
# | Criminal non-support                                       |     1 |
# | Reckless driving                                           |     1 |
# | burglary                                                   |     1 |
# | Possesion of cocaine                                       |     1 |
# | No insurance                                               |     1 |
# | Possession of marijuana less than 2 oz                     |     1 |
# | Possession firearm by a felon                              |     1 |
# | Impersonating a police officer                             |     1 |
# | Violation of Protective Family Violence                    |     1 |
# | Burglary assault                                           |     1 |
# | Interfering with child custody                             |     1 |
# | Interfering with police duties                             |     1 |
# | Capital murder                                             |     1 |
# | Armed robbery                                              |     1 |
# | Arson                                                      |     1 |
# | Burglary of a habitat with intent to commit sexual assault |     1 |
# | Homicide                                                   |     1 |
# | Attempted robbery                                          |     1 |
# | Failure to stop and give information                       |     1 |
# | Seatbelt violation                                         |     1 |

# %%
# print the list of offenses and their ID
# The IDs are used to build the minor_offenses
offenses_table.order_by('id').print_table(max_rows=None, max_column_width=None)
# Out:
# | id | offense                                                    |
# | -- | ---------------------------------------------------------- |
# |  1 | Theft $50-$500                                             |
# |  2 | Aggravated assault with a deadly weapon                    |
# |  3 | Evading arrest                                             |
# |  5 | Criminal mischief                                          |
# |  6 | Assault on public servant                                  |
# |  7 | DWI                                                        |
# |  8 | Resisting arrest                                           |
# |  9 | Public intoxication                                        |
# | 10 | Aggravated robbery                                         |
# | 12 | Assault family violence                                    |
# | 13 | Burglary of a habitation                                   |
# | 14 | Criminal trespass                                          |
# | 15 | Disorderly conduct                                         |
# | 16 | Discharging a weapon in city limits                        |
# | 17 | Possession of a controlled substance                       |
# | 18 | Capital murder                                             |
# | 19 | Driving without a license                                  |
# | 21 | Assault of a child                                         |
# | 24 | Aggravated assault                                         |
# | 26 | Traffic violations                                         |
# | 27 | Seatbelt violation                                         |
# | 28 | Tampering with evidence                                    |
# | 29 | Outstanding warrants                                       |
# | 30 | APOWW/mental health hold                                   |
# | 31 | Assault                                                    |
# | 32 | Parole violation                                           |
# | 33 | Failure to stop and render aid                             |
# | 34 | False identification                                       |
# | 35 | Theft <$20,000                                             |
# | 36 | Interfering with police duties                             |
# | 37 | None listed                                                |
# | 38 | Burglary of motor vehicle                                  |
# | 39 | Manufacture/distribution of controlled substance           |
# | 40 | Robbery                                                    |
# | 41 | Domestic violence                                          |
# | 42 | Possession drug paraphernalia                              |
# | 43 | Possession firearm by a felon                              |
# | 44 | Probation revocation                                       |
# | 45 | Unauthorized use of motor vehicle                          |
# | 47 | Burglary of a habitat with intent to commit sexual assault |
# | 48 | Possession/use abusable volatile chemical (inhalant)       |
# | 49 | Attempted robbery                                          |
# | 50 | Taking or attempting to take weapon from peace officer     |
# | 51 | Failure to stop and give information                       |
# | 52 | Indecent exposure                                          |
# | 53 | Interfering with child custody                             |
# | 54 | Armed robbery                                              |
# | 55 | Homicide                                                   |
# | 56 | Criminal non-support                                       |
# | 57 | Reckless driving                                           |
# | 58 | Arson                                                      |

# %% [markdown]
# ### Set the list that constitute 'suspect' offenses
#
# The list of offenses we will consider minor for this analysis:
#
# - 3: Evading arrest
# - 5: Criminal mischief
# - 6: Assault on public servant
# - 8: Resisting arrest
# - 9: Public intoxication
# - 14: Criminal trespass
# - 15: Disorderly conduct
# - 19: Driving without a license
# - 26: Traffic violations
# - 27: Seatbelt violation
# - 28: Tampering with evidence
# - 30: APOWW/mental health hold
# - 34: False identification
# - 36: Interfering w/ police duties
# - 37: None listed
# - 42: Possession of drug paraphernalia
# - 51: Failure to stop and give information

# %%
# This set the list to be evaluated later
# in the suspect_offense_check function
suspect_offenses = ['3','5','6','8','9','14','15','19','26','27',
                    '28','30','34','36','37','42','45','51',''] #leave last item blank

infractions_story_list = ['3', '8', '9', '17', '42', '48', '30', '37']

resist_arrest_only = ['3','8']

public_intox = ['9']

mental_health = ['30']

traffic_violations = ['19', '27', '26']

drug_possession = ['17', '42', '48']

interference = ['36']

none_listed = ['37']

# %%
# We'll select just the columns we need from deaths.
deaths_offenses = deaths.select(['first_name', 'middle_name', 'last_name', 'offense']).order_by('last_name')

# and we pee at those columns:
print(deaths_offenses)
# Out:
# | column      | data_type |
# | ----------- | --------- |
# | first_name  | Text      |
# | middle_name | Text      |
# | last_name   | Text      |
# | offense     | Text      |

# %%
# Printing the whole table here so we can compare
# against our filtered table later
# also, there should be no blanks for offense
deaths_offenses.print_table(max_rows=None)
# Out:
# | first_name  | middle_name   | last_name        | offense  |
# | ----------- | ------------- | ---------------- | -------- |
# | Pierre      | Tourell       | Abernathy        | 7,3,8    |
# | Jesse       |               | Aguirre          | 5,35     |
# | Sam         |               | Akin             | 12       |
# | Timothy     |               | Alfaro           | 14,9     |
# | Steven      | Lee           | Allen            | 48       |
# | Raymond     | Luther        | Allen            | 9,8      |
# | Jamail      | Joseph        | Amron            | 37       |
# | Ross        | Allen         | Anthony          | 30       |
# | Corey       | Dean          | Bailey           | 7        |
# | Weldon      | Davis         | Baker            | 5        |
# | Manuel      | A.            | Baltazar         | 6        |
# | Willie      | Ray           | Banks            | 6,9      |
# | Herman      |               | Barnes           | 37       |
# | Osbaldo     | Xavier        | Barrera          | 64,65    |
# | Alfredo     |               | Barrientos       | 31,8     |
# | Richard     | Eduardo       | Battistata       | 6,13     |
# | John        | Paul          | Bazan            | 6,8      |
# | Antonie     | D             | Bell             | 19,60,61 |
# | Frank       | Timothy       | Benavides        | 30       |
# | Derrick     | Anthony       | Birdow           | 18       |
# | Magnolia    | Lucille       | Blakeman         | 9        |
# | Charles     | Edward        | Boll             | 15       |
# | Dustin      | Michael       | Brown            | 29       |
# | Anthony     | George        | Brown            | 6        |
# | Robert      |               | Bushnell         | 26       |
# | Joseph      |               | Cain             | 31       |
# | Curtis      | Wayne         | Camille          | 43,17    |
# | Craig       |               | Campbell         | 1        |
# | Inocencio   | Juarez        | Cardenas         | 6,8      |
# | Ernesto     |               | Carraman         | 30       |
# | Juan        |               | Carrizales       | 21       |
# | Roque       |               | Carrizales       | 17       |
# | Joel        | Don           | Casey            | 37       |
# | Michael     | Shea          | Cassel           | 13,3     |
# | Wilber      |               | Castillo-Gongora | 3        |
# | Charles     | Albert        | Cathey           | 13       |
# | Denis       | John          | Chabot           | 3        |
# | Michael     | Anthony       | Charles          | 28       |
# | Jean        | Yves          | Charles          | 3,17     |
# | Jerry       | Guildwin      | Choate           | 7        |
# | Rodolfo     |               | Cisneros         | 9,8      |
# | Michael     |               | Clark            | 9        |
# | Shane       | Weston        | Cook             | 10,3,32  |
# | Norman      | Lee           | Cooper           | 24,13,3  |
# | William     | Dylan         | Cooper           | 14,8     |
# | Lawrence    | Phinehas      | Crain            | 30       |
# | Greg        |               | Cranfill         | 9        |
# | Dougressa   | Elaine        | Crawford         | 6        |
# | Judith      | Davila        | Cruz             | 2        |
# | Louis       | Jacoby        | Cryer            | 13       |
# | Carolyn     | Jean          | Daniels          | 9        |
# | Jermaine    | Nicholas      | Darden           | 39,17    |
# | Noel        |               | Davila           | 9        |
# | Billy       | Ray           | Davis            | 37       |
# | Ronnie      | Keith         | Davis            | 15       |
# | Jerome      | Allen         | Davis            | 6,5,8    |
# | Jesse       | Andrew        | DeBusk           | 29       |
# | Manuel      |               | Delacruz         | 50       |
# | Todd        |               | Deveyra          | 6,7      |
# | James       |               | Dortch           | 12,8     |
# | Alton       | Gene          | Dragoo           | 35       |
# | Brady       | Allan         | Dustman          | 6        |
# | Graham      | Edward        | Dyer             | 6,9,8    |
# | Kenneth     |               | Eagleton         | 37       |
# | Robert      | Brandon       | Edwards          | 9        |
# | Clancy      | Aaron         | Edwards          | 9        |
# | Tyree       | Sinclair      | Edwards          | 3,8      |
# | Hector      | Hugo          | Elizondo         | 5,9,8    |
# | Marcus      | Nygel         | Elliott          | 54       |
# | Mario       |               | Evans            | 9        |
# | Joe         |               | Faltesek         | 6        |
# | Jeremiah    | Lamar         | Farris           | 3        |
# | Allen       |               | Fenley           | 10,6,55  |
# | Michael     | Anthony       | Ferrell          | 44       |
# | James       | Christopher   | Flory            | 14,8     |
# | Michael     | Dean          | Ford             | 3,8      |
# | Jacob       | Bernard       | Ford             | 3,1      |
# | Jose        |               | Franco           | 3,34,8   |
# | William     | Yendis        | Franklin         | 42,17    |
# | Gene        | Baraka        | Franklin         | 17,26    |
# | Nancy       | Lynn          | Friedrich        | 30,9     |
# | Sergio      |               | Galvan           | 30       |
# | Macario     | Cisneros      | Garcia           | 3,8      |
# | Silvestre   |               | Garcia           | 31       |
# | Ramiro      | Rodriguez     | Garcia           | 9,8      |
# | Joe         | Anthony       | Garcia           | 9,8      |
# | Sergio      | Martin        | Garcia           | 8        |
# | Madeline    |               | Garcia           | 9        |
# | David       |               | Garza            | 31,13    |
# | Jami        |               | Gaubatz          | 9        |
# | Rosendo     |               | Gaytan           | 6,17,9   |
# | Dustin      | Keith         | Glover           | 6        |
# | Stacy       | Zimbalist     | Golston          | 9        |
# | Fernando    |               | Gomez            | 3,8      |
# | Mark        | Anthony       | Gonzales         | 8        |
# | David       | Mercado       | Gonzalez         | 6,32,8   |
# | Juan        | Marcos        | Gonzalez         | 6,8      |
# | Mark        | Spotswood     | Green            |          |
# | Barney      | Lee           | Green            | 17       |
# | Rodney      | Earl          | Green            | 8        |
# | Oliver      | Jarrod        | Gregorie         | 24,13    |
# | Daniel      | Lee           | Guerra           | 16,3,17  |
# | Jesse       |               | Guerrero         |          |
# | Kevin       |               | Hafstienn        | 26       |
# | Surleslie   | Eugene        | Hall             | 63       |
# | Eric        | Jay           | Hammock          | 5,3,8    |
# | Curtis      | Michael       | Harwell          | 13       |
# | Steven      |               | Hayes            | 8        |
# | James       | Edward        | Haywood          | 17       |
# | Jonas       |               | Hernandez        | 14,8     |
# | Jesus       |               | Hernandez        | 30       |
# | Salvador    |               | Hernandez        | 9        |
# | Frank       | W.            | Hernandez        | 37       |
# | Milton      | Heath         | Hill             | 29       |
# | Cedric      | Dale          | Hill             | 6        |
# | Johnny      | Anthony       | Hooper           | 3,17     |
# | Terrell     | Leray         | Houston          | 14,3,8   |
# | Joseph      | Sheldon       | Hutcheson        | 9,8      |
# | Christopher | Chadd         | Irwin            |          |
# | Steven      | Michael       | Irwin            | 17       |
# | Joshua      | Carl          | Ivy              | 42       |
# | Al          | Dwaun         | Jackson          | 49       |
# | Donald      | Wayne         | Jacobs           | 5        |
# | Michael     | Patrick       | Jacobs           | 30       |
# | Michael     | Isaac         | James            | 30       |
# | Christopher | Stewart       | James            | 9,8      |
# | Teresa      | Yvonne        | James            | 37       |
# | Branndon    | C.            | Jefferson        | 37       |
# | Keith       | Leo           | Jenkins          | 29       |
# | Jose        | Alfred        | Jimenez          | 6,3      |
# | Jonathan    | Lee           | Johnson          | 13       |
# | Tyrone      | Ulrich        | Jones            | 6        |
# | Jerry       | Lynn          | Jones            | 13       |
# | Dustin      | Keith         | Jones            | 24,10,21 |
# | Daryl       | Dwayne        | Kelley           | 45       |
# | Carl        | Lee           | Kelley           | 5        |
# | Micah       | Anthony       | Key              | 12,8     |
# | John        | Yongwoo       | Kim              | 17,28    |
# | Michael     | Wayne         | King             | 17       |
# | Thomas      | Joseph        | Kirksey          | 39       |
# | Gregory     | Maurice       | Kitchen          | 47       |
# | Thomas      | E.            | Klessig          | 6,3      |
# | Herman      | George        | Knabe            | 3,8      |
# | Dalton      | Dakota        | Knott            | 40       |
# | Brandon     | Lee           | Kort             | 30       |
# | Kevin       | Jibreel       | Laday            | 6,3,8    |
# | Shawn       | Renee         | Larochelle       | 6,29     |
# | Keith       |               | Latin            | 3        |
# | Darrell     |               | Lauderdale       | 9        |
# | Tadarion    | Deshon        | Lawson           | 12       |
# | Larry       | Earl          | Leaks            |          |
# | Erick       | Damon         | Lee              | 6        |
# | Shawn       | Ellis         | Leflore          | 19,3     |
# | Robert      |               | Lerma            | 30       |
# | Shmekia     | Rena Shyontay | Lewis            | 6,42,8   |
# | Curtis      | Lee           | Lewis            | 30       |
# | Jason       | Kyle          | Lewis            | 6        |
# | Gilberto    |               | Limon            | 8        |
# | William     |               | Livezey          | 2        |
# | Freddie     | Lee           | Lockett          | 40       |
# | Qwame       | Maulan        | Lombardo         | 12,13    |
# | Pedro       | Serifino      | Longoria         | 1        |
# | Juan        | Flores        | Lopez            | 24,58    |
# | Noah        | Ray           | Lopez            | 6,9      |
# | Angel       | Rodriguez     | Lopez            | 19,7,3   |
# | Levon       | Leroy         | Love             | 33       |
# | Juan        | Antonio       | Lozano           | 8        |
# | Kenneth     | Christopher   | Lucas            | 12,53    |
# | Cory        | Christopher   | Lucero           | 62       |
# | Bobby       | Joe           | Madewell         | 2        |
# | Jesus       | Tadeo         | Magana           | 38       |
# | Wesley      | Wayne         | Manning          | 6,36,8   |
# | Jose        | Luis          | Martinez         | 9        |
# | Michael     | Andrea        | Martinez         | 26       |
# | Luis        | Alfonso       | Martinez         | 7        |
# | Carlos      |               | Mata             | 17       |
# | Joe         | Toby          | Mata             | 37       |
# | Michael     |               | McKnight         | 29       |
# | Dawn        | Nicole        | McLemore         | 17,28    |
# | Randy       | Lee           | McSmith          | 41,8     |
# | Miguel      | Alonzo        | Mendoza          | 3,17     |
# | Ben         | Tarell        | Miller           | 24       |
# | Christopher | Marshall      | Monroe           | 6,3,52   |
# | Marshall    |               | Moreno           | 9        |
# | Bryan       | Lee           | Morton           | 17,8     |
# | Ernest      | Lane          | Muller           | 44       |
# | Casey       | Edward        | Nessing          | 9        |
# | Thahn       |               | Nguyen           | 5,14,15  |
# | Juan        | Manuel        | Nunez            | 15,9     |
# | Courtenay   | Jermaine      | O'Bryant         | 17,27,28 |
# | Carl        | James         | O'Neal           | 17,8     |
# | Dennis      | Demarcus      | Oatis            | 31,5     |
# | Jorge       |               | Ochoa            | 9        |
# | Francisco   | Ray           | Olivarez         | 17       |
# | Micheal     |               | Olveda           | 29       |
# | Adan        | Zarate        | Olvera           | 24,17    |
# | Kevin       | Ray           | Omas             | 9,8      |
# | Silviano    |               | Ortiz            | 9,8      |
# | John        | Winston       | Ozuna            | 30       |
# | Jose        | Ignacio       | Palomo           | 9        |
# | Richard     | Vincent       | Pando            | 9,8      |
# | Stacy       | Tyrone        | Paris            | 9        |
# | Winfred     | Terrill       | Parker           | 12       |
# | Richard     | Lee           | Parr             | 3,8      |
# | Johnell     |               | Patrick          | 29       |
# | Jonathan    | Ryan          | Paul             | 29,26    |
# | Andre       | Ramon         | Payne            | 19       |
# | Dashaun     | H.            | Pearson          | 24       |
# | Michael     | Louis         | Peden            | 56,3,8   |
# | David       | Michael       | Pedersen         | 9,8      |
# | Mario       | Anthony       | Pedigone         | 30       |
# | Juan        | Jose          | Perez            | 2,6      |
# | Alexander   |               | Peschard         | 17,26    |
# | Joseph      | Anthony       | Pihota           | 37       |
# | Wayne       | Fletcher      | Pratt            | 51,8     |
# | Andre       |               | Prince           | 37       |
# | Joseph      |               | Ramage           | 30       |
# | Elvis       | Joel          | Ramirez          | 17,9     |
# | Jose        | DeJesus       | Ramirez          | 9        |
# | Joe         | Ernest        | Ramos            | 8        |
# | Eric        | Lee           | Ray              | 14       |
# | Johnny      | Curtis        | Reeves           | 52       |
# | Donaciano   | Sotelo        | Rendon           | 41,17,8  |
# | Lance       |               | Revalee          | 9        |
# | John        | Damon         | Revis            | 14       |
# | Juan        | Carlos        | Reyes-Gallardo   | 9        |
# | Thomas      | Donald        | Rice             | 2        |
# | Eric        | Ladale        | Ricks            | 6        |
# | Michael     | Shunn         | Roberson         | 9        |
# | Jesse       | Jameiel       | Robins           | 28       |
# | Johnny      | Jimmy         | Robles           | 29       |
# | Hector      |               | Rodriguez        | 9        |
# | Antonio     | Santiago      | Rodriguez        | 31,8     |
# | Paul        |               | Rodriguez        | 15       |
# | Jose        |               | Romero           | 24       |
# | Douglas     | Dewayne       | Roof             | 30       |
# | Tony        | Chance        | Ross             | 6,8      |
# | Kristoper   |               | Rupe             | 5,9      |
# | Jesus       |               | Salas            | 48       |
# | Joseph      | John          | Sanchez          | 38       |
# | Dawaski     | Kewa          | Sanders          | 30       |
# | Marcos      | Antino        | Sariento         | 7        |
# | Efrain      | Agapito       | Sauceda          | 19       |
# | Jose        |               | Sauceda          | 7,8      |
# | Kenneth     | Neil          | Schlanker        | 5,9      |
# | Elmore      |               | Segura           | 17       |
# | Micah       | Theron        | Shepard          | 7        |
# | Jonathan    | Lemar         | Simon            | 30       |
# | Kelly       | Wayne         | Sinclair         | 2,45     |
# | James       | Fred          | Sizer            | 16       |
# | Marcus      | Dewayne       | Slade            | 6,15,8   |
# | Richard     |               | Smith            | 31,8     |
# | Rafael      | Edgar         | Solis            | 29       |
# | Michael     | Anthony       | Solis            | 13       |
# | Nicolas     | Castillo      | Soria            | 13       |
# | Shirley     | Ann           | South            | 38       |
# | Troy        | Marcus        | Stewart          | 30       |
# | Lorenzo     | Charles       | Stiggers         | 9        |
# | Teddy       |               | Stranghoener     | 30       |
# | Lesa        | Ann           | Surratt          | 17       |
# | Elcide      | Gabriel       | Sylve            | 9        |
# | Daniel      | Rivera        | Tamez            | 3,57,8   |
# | John        | Steven        | Thomas           | 5,9,8    |
# | Kinzy       | Laquinte      | Thornton         | 6        |
# | Anthony     |               | Timpa            | 30       |
# | Thuan       |               | Tran             |          |
# | Aladino     |               | Trejo            | 9        |
# | Alisha      |               | Trevino          | 39       |
# | Jeffery     | Garlin        | Trotter          | 10       |
# | Adren       | Maurice       | Turner           | 7        |
# | Jamaal      | Ray           | Valentine        | 9        |
# | Noe         |               | Vera             | 6,5,14   |
# | Edgar       | Alejandro     | Vera             | 8        |
# | Richard     | Joseph        | Verrett          | 12       |
# | Omar        |               | Villanueva-Rojas | 31       |
# | Michael     | Corleone      | Villareal        | 17       |
# | Coy         | Wayne         | Walker           | 6,8      |
# | Willie      | Lee           | Washington       | 17       |
# | Jimmy       | Lloyd         | Washington       | 6,13     |
# | Billy       |               | Weckar           | 59       |
# | Robert      | Lee           | Welch            | 8        |
# | Gary        | James         | Wells            | 30,9     |
# | Terry       | Wayne         | White            | 9        |
# | Robert      | Earl          | Williams         | 14,29    |
# | Wade        | Devin         | Wilson           | 17       |
# | Marion      |               | Wilson           | 6,3,17   |
# | Joey        | Clayton       | Wood             | 9        |
# | Robert      | Neil          | Woods            | 3,26     |
# | Jack        | Lee           | Young            | 9        |

# %% [markdown]
# ### Suspect charges function
#
# Sometimes there are cases where charges were very minor to begin with, or charges were the result of the police interaction, and would not have happened otherwise. This process builds a list of cases to investigate further.
#
# The function evaluates the offenses in a given row:
# - If the offense field is blank, we keep it. (There shouldn't be ... those cases should have the "None listed" option.)
# - If the offense field has an offense listed that is NOT in the suspect offenses list, it is skipped
# - If what you are left with is just suspect offenses or blank, we keep it
#
# We store all that in a new table and then print it.

# %%
# This is ONLY OFFENSES evaluation function
# It looks at the list of offenses in a row and then compares it
# against offense_list, which is a list passed into the function.
# It returns only rows where charges match the offense_list.
# if there are any others, the row is rejected

def offense_check(row, offense_list):
    if row is None:
        return True
    myList = row.split(',')
    for item in myList:
        if item not in offense_list:
            return False
    return True

# %%
# this filters our death_offenses table based on the 
# minor_offense_check function above, and then creates
# a new table of just those rows that pass
suspect_offense_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], suspect_offenses))
print('Records with only "suspect" offenses: {} or {:.1%}\n'.format(
    len(suspect_offense_cases),
    len(suspect_offense_cases) / len(deaths_offenses)
    ))
# prints the deaths with just minor offenses
suspect_offense_cases.print_table(max_rows=None)
# Out:
# Records with only "suspect" offenses: 159 or 55.0%
#
# | first_name  | middle_name   | last_name        | offense |
# | ----------- | ------------- | ---------------- | ------- |
# | Timothy     |               | Alfaro           | 14,9    |
# | Raymond     | Luther        | Allen            | 9,8     |
# | Jamail      | Joseph        | Amron            | 37      |
# | Ross        | Allen         | Anthony          | 30      |
# | Weldon      | Davis         | Baker            | 5       |
# | Manuel      | A.            | Baltazar         | 6       |
# | Willie      | Ray           | Banks            | 6,9     |
# | Herman      |               | Barnes           | 37      |
# | John        | Paul          | Bazan            | 6,8     |
# | Frank       | Timothy       | Benavides        | 30      |
# | Magnolia    | Lucille       | Blakeman         | 9       |
# | Charles     | Edward        | Boll             | 15      |
# | Anthony     | George        | Brown            | 6       |
# | Robert      |               | Bushnell         | 26      |
# | Inocencio   | Juarez        | Cardenas         | 6,8     |
# | Ernesto     |               | Carraman         | 30      |
# | Joel        | Don           | Casey            | 37      |
# | Wilber      |               | Castillo-Gongora | 3       |
# | Denis       | John          | Chabot           | 3       |
# | Michael     | Anthony       | Charles          | 28      |
# | Rodolfo     |               | Cisneros         | 9,8     |
# | Michael     |               | Clark            | 9       |
# | William     | Dylan         | Cooper           | 14,8    |
# | Lawrence    | Phinehas      | Crain            | 30      |
# | Greg        |               | Cranfill         | 9       |
# | Dougressa   | Elaine        | Crawford         | 6       |
# | Carolyn     | Jean          | Daniels          | 9       |
# | Noel        |               | Davila           | 9       |
# | Billy       | Ray           | Davis            | 37      |
# | Ronnie      | Keith         | Davis            | 15      |
# | Jerome      | Allen         | Davis            | 6,5,8   |
# | Brady       | Allan         | Dustman          | 6       |
# | Graham      | Edward        | Dyer             | 6,9,8   |
# | Kenneth     |               | Eagleton         | 37      |
# | Robert      | Brandon       | Edwards          | 9       |
# | Clancy      | Aaron         | Edwards          | 9       |
# | Tyree       | Sinclair      | Edwards          | 3,8     |
# | Hector      | Hugo          | Elizondo         | 5,9,8   |
# | Mario       |               | Evans            | 9       |
# | Joe         |               | Faltesek         | 6       |
# | Jeremiah    | Lamar         | Farris           | 3       |
# | James       | Christopher   | Flory            | 14,8    |
# | Michael     | Dean          | Ford             | 3,8     |
# | Jose        |               | Franco           | 3,34,8  |
# | Nancy       | Lynn          | Friedrich        | 30,9    |
# | Sergio      |               | Galvan           | 30      |
# | Macario     | Cisneros      | Garcia           | 3,8     |
# | Ramiro      | Rodriguez     | Garcia           | 9,8     |
# | Joe         | Anthony       | Garcia           | 9,8     |
# | Sergio      | Martin        | Garcia           | 8       |
# | Madeline    |               | Garcia           | 9       |
# | Jami        |               | Gaubatz          | 9       |
# | Dustin      | Keith         | Glover           | 6       |
# | Stacy       | Zimbalist     | Golston          | 9       |
# | Fernando    |               | Gomez            | 3,8     |
# | Mark        | Anthony       | Gonzales         | 8       |
# | Juan        | Marcos        | Gonzalez         | 6,8     |
# | Mark        | Spotswood     | Green            |         |
# | Rodney      | Earl          | Green            | 8       |
# | Jesse       |               | Guerrero         |         |
# | Kevin       |               | Hafstienn        | 26      |
# | Eric        | Jay           | Hammock          | 5,3,8   |
# | Steven      |               | Hayes            | 8       |
# | Jonas       |               | Hernandez        | 14,8    |
# | Jesus       |               | Hernandez        | 30      |
# | Salvador    |               | Hernandez        | 9       |
# | Frank       | W.            | Hernandez        | 37      |
# | Cedric      | Dale          | Hill             | 6       |
# | Terrell     | Leray         | Houston          | 14,3,8  |
# | Joseph      | Sheldon       | Hutcheson        | 9,8     |
# | Christopher | Chadd         | Irwin            |         |
# | Joshua      | Carl          | Ivy              | 42      |
# | Donald      | Wayne         | Jacobs           | 5       |
# | Michael     | Patrick       | Jacobs           | 30      |
# | Michael     | Isaac         | James            | 30      |
# | Christopher | Stewart       | James            | 9,8     |
# | Teresa      | Yvonne        | James            | 37      |
# | Branndon    | C.            | Jefferson        | 37      |
# | Jose        | Alfred        | Jimenez          | 6,3     |
# | Tyrone      | Ulrich        | Jones            | 6       |
# | Daryl       | Dwayne        | Kelley           | 45      |
# | Carl        | Lee           | Kelley           | 5       |
# | Thomas      | E.            | Klessig          | 6,3     |
# | Herman      | George        | Knabe            | 3,8     |
# | Brandon     | Lee           | Kort             | 30      |
# | Kevin       | Jibreel       | Laday            | 6,3,8   |
# | Keith       |               | Latin            | 3       |
# | Darrell     |               | Lauderdale       | 9       |
# | Larry       | Earl          | Leaks            |         |
# | Erick       | Damon         | Lee              | 6       |
# | Shawn       | Ellis         | Leflore          | 19,3    |
# | Robert      |               | Lerma            | 30      |
# | Shmekia     | Rena Shyontay | Lewis            | 6,42,8  |
# | Curtis      | Lee           | Lewis            | 30      |
# | Jason       | Kyle          | Lewis            | 6       |
# | Gilberto    |               | Limon            | 8       |
# | Noah        | Ray           | Lopez            | 6,9     |
# | Juan        | Antonio       | Lozano           | 8       |
# | Wesley      | Wayne         | Manning          | 6,36,8  |
# | Jose        | Luis          | Martinez         | 9       |
# | Michael     | Andrea        | Martinez         | 26      |
# | Joe         | Toby          | Mata             | 37      |
# | Marshall    |               | Moreno           | 9       |
# | Casey       | Edward        | Nessing          | 9       |
# | Thahn       |               | Nguyen           | 5,14,15 |
# | Juan        | Manuel        | Nunez            | 15,9    |
# | Jorge       |               | Ochoa            | 9       |
# | Kevin       | Ray           | Omas             | 9,8     |
# | Silviano    |               | Ortiz            | 9,8     |
# | John        | Winston       | Ozuna            | 30      |
# | Jose        | Ignacio       | Palomo           | 9       |
# | Richard     | Vincent       | Pando            | 9,8     |
# | Stacy       | Tyrone        | Paris            | 9       |
# | Richard     | Lee           | Parr             | 3,8     |
# | Andre       | Ramon         | Payne            | 19      |
# | David       | Michael       | Pedersen         | 9,8     |
# | Mario       | Anthony       | Pedigone         | 30      |
# | Joseph      | Anthony       | Pihota           | 37      |
# | Wayne       | Fletcher      | Pratt            | 51,8    |
# | Andre       |               | Prince           | 37      |
# | Joseph      |               | Ramage           | 30      |
# | Jose        | DeJesus       | Ramirez          | 9       |
# | Joe         | Ernest        | Ramos            | 8       |
# | Eric        | Lee           | Ray              | 14      |
# | Lance       |               | Revalee          | 9       |
# | John        | Damon         | Revis            | 14      |
# | Juan        | Carlos        | Reyes-Gallardo   | 9       |
# | Eric        | Ladale        | Ricks            | 6       |
# | Michael     | Shunn         | Roberson         | 9       |
# | Jesse       | Jameiel       | Robins           | 28      |
# | Hector      |               | Rodriguez        | 9       |
# | Paul        |               | Rodriguez        | 15      |
# | Douglas     | Dewayne       | Roof             | 30      |
# | Tony        | Chance        | Ross             | 6,8     |
# | Kristoper   |               | Rupe             | 5,9     |
# | Dawaski     | Kewa          | Sanders          | 30      |
# | Efrain      | Agapito       | Sauceda          | 19      |
# | Kenneth     | Neil          | Schlanker        | 5,9     |
# | Jonathan    | Lemar         | Simon            | 30      |
# | Marcus      | Dewayne       | Slade            | 6,15,8  |
# | Troy        | Marcus        | Stewart          | 30      |
# | Lorenzo     | Charles       | Stiggers         | 9       |
# | Teddy       |               | Stranghoener     | 30      |
# | Elcide      | Gabriel       | Sylve            | 9       |
# | John        | Steven        | Thomas           | 5,9,8   |
# | Kinzy       | Laquinte      | Thornton         | 6       |
# | Anthony     |               | Timpa            | 30      |
# | Thuan       |               | Tran             |         |
# | Aladino     |               | Trejo            | 9       |
# | Jamaal      | Ray           | Valentine        | 9       |
# | Noe         |               | Vera             | 6,5,14  |
# | Edgar       | Alejandro     | Vera             | 8       |
# | Coy         | Wayne         | Walker           | 6,8     |
# | Robert      | Lee           | Welch            | 8       |
# | Gary        | James         | Wells            | 30,9    |
# | Terry       | Wayne         | White            | 9       |
# | Joey        | Clayton       | Wood             | 9       |
# | Robert      | Neil          | Woods            | 3,26    |
# | Jack        | Lee           | Young            | 9       |

# %% [markdown]
# ### List number of cases in specific groupings
#
# The groupings are set above where we list out all the offense IDs.

# %%
suspect_offense_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], suspect_offenses))
print('Records with only "suspect" offenses: {} or {:.1%}\n'.format(
    len(suspect_offense_cases),
    len(suspect_offense_cases) / len(deaths_offenses)
    ))

infraction_story_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], infractions_story_list))
print('Records for infraction story offenses: {} or {:.1%}\n'.format(
    len(infraction_story_cases),
    len(infraction_story_cases) / len(deaths_offenses)
    ))

resist_evade_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], resist_arrest_only))
print('Records with only Resisting or Evading Arrest charges: {} for {:.1%}\n'.format(
        len(resist_evade_cases),
        len(resist_evade_cases)/ len(deaths_offenses)
    ))

public_intox_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], public_intox))
print('Records with only Public Intoxication charge: {} for {:.1%}\n'.format(
        len(public_intox_cases),
        len(public_intox_cases)/ len(deaths_offenses)
    ))

mental_health_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], mental_health))
print('Records with only Mental Health charge: {} for {:.1%}\n'.format(
        len(mental_health_cases),
        len(mental_health_cases)/ len(deaths_offenses)
    ))

traffic_violations_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], traffic_violations))
print('Records with only Traffic Violation charges: {} for {:.1%}\n'.format(
        len(traffic_violations_cases),
        len(traffic_violations_cases)/ len(deaths_offenses)
    ))

drug_possession_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], drug_possession))
print('Records with only Drug Possession charges: {} for {:.1%}\n'.format(
        len(drug_possession_cases),
        len(drug_possession_cases)/ len(deaths_offenses)
    ))

interference_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], interference))
print('Records with only Interference charges: {} for {:.1%}\n'.format(
        len(interference_cases),
        len(interference_cases)/ len(deaths_offenses)
    ))

none_cases = deaths_offenses.where(lambda row: offense_check(row['offense'], none_listed))
print('Records with only "None listed" charges: {} for {:.1%}\n'.format(
        len(none_cases),
        len(none_cases)/ len(deaths_offenses)
    ))
# Out:
# Records with only "suspect" offenses: 159 or 55.0%
#
# Records for infraction story offenses: 120 or 41.5%
#
# Records with only Resisting or Evading Arrest charges: 24 for 8.3%
#
# Records with only Public Intoxication charge: 36 for 12.5%
#
# Records with only Mental Health charge: 25 for 8.7%
#
# Records with only Traffic Violation charges: 10 for 3.5%
#
# Records with only Drug Possession charges: 21 for 7.3%
#
# Records with only Interference charges: 5 for 1.7%
#
# Records with only "None listed" charges: 16 for 5.5%
